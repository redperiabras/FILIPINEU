# %%
import subprocess

# %%
source = open('source.data.eval', 'r')
# output = open('smt-result.data.eval', 'w')
output = []

data = source.readlines()

for datum in data:
    command = "thot_client -i localhost -t '" + datum + "'"
    p = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    for line in p.stdout.readlines():
        print(line.decode('utf-8'))
#         output.write(line.decode('utf-8') + "\n")
        output.append(line.decode('utf-8'))
    retval = p.wait()

source.close()
# Out:
# where is the station skytrain ?
#
#
#
# bye and this is good luck !
#
#
#
# naririto the no.6 . tara .
#
#
#
# buy we an old vans and lumibot in california ride it .
#
#
#
# yes , i went with is the friend to is david .
#
#
#
# if no , you have to add fee since you did not susuklian of driver .
#
#
#
# i am sure i maliligayahan you , madam .
#
#
#
# are nakatutuwang match ? recently ?
#
#
#
# i would like to confirm my reservation .
#
#
#
# nakapag-skating tour you have with you which is ?
#
#
#
# it is my first visit .
#
#
#
# no more are leaf are full now .
#
#
#
# can i reserve a cushioned berth in express today ?
#
#
#
# can you turuan least next week ?
#
#
#
# send ? the luggage to the same train with i do ?
#
#
#
# is this your first paglakbay ?
#
#
#
# should take is the ferry to ports of wang lang.
#
#
#
# no , thank you . maybe too i tired after is the trip .
#
#
#
# suitable is take ten before the ala first ?
#
#
#
# where is the the dining car ?
#
#
#
# after go sightseeing , i will go back to the taiwan .
#
#
#
# i suggest you reserve you will have to get a ticket berth for surat , because if you get off to surat , it will be your ticket is invalid to berth to phayao .
#
#
#
# i want to fly to san francisco wednesday the 5th .
#
#
#
# that is very kind of you , sir , but we cannot accept tips . with 10 % service charge in addition on your bill .
#
#
#
# dinner
#
#
#
# i will ring you up .
#
#
#
# three way and is one
#
# /bin/sh: 2: Syntax error: Unterminated quoted string
#
# i am paying for harm done i
#
#
#
# please be careful in the pagdadala it .
#
#
#
# here is your receipt .
#
#
#
# do you have a table the window ?
#
#
#
# please wait here .
#
#
#
# can i have a sailboard ?
#
#
#
# do you have any free room in the hotel ?
#
#
#
# you need to listen to the are brodkast in the train .
#
#
#
# suggest to ask no the police to would be over there .
#
#
#
# i would like to fly to bangkok . which the best way ?
#
#
#
# binawi is his license for driving a little lasing.
#
#
#
# i do not iniinom the tea with milk .
#
#
#
# it is the special price .
#
#
#
# should i change trains anywhere if i am leaving for beijing ?
#
#
#
# natumba the nagbibisikleta , it looks serious the injury .
#
#
#
# what have you have in the way of toilet soap ?
#
#
#
# where is the kartilya for baggage ?
#
#
#
# i sent at home my luggage as not sinamahang luggage .
#
#
#
# there pababang pangski with good sights ?
#
#
#
# we will not charge you .
#
#
#
# could you send some for my laundry , please ?
#
#
#
# fish in the foil fried over hot coal
#
#
#
# i would like a better things .
#
#
#
# look at the babaeng police in the tawiran .
#
#
#
# it has a very delicate taste .
#
#
#
# that is the famous parada of staff of walt disney .
#
#
#
# where the downtown ?
#
#
#
# not duty free the horrible goods .
#
#
#
# this is the check card .
#
#
#
# please bring me a seasoning.
#
#
#
# can we get there a little about ten minutes ?
#
#
#
# signs say guess will a storm now .
#
#
#
# how are you ?
#
#
#
# turn right you after just last banko .
#
#
#
# a movie aksyon .
#
#
#
# i will notify you if there is cancellation .
#
#
#
# fits well . how is left ?
#
#
#
# boiled rice soup
#
#
#
# have any others ? ?
#
#
#
# including have been added to your bill 10 % tax and 10 % service charge .
#
#
#
# do you have any fever ?
#
#
#
# some knots the nagagawa he in his pinakamagaling ?
#
#
#
# not my earphones are working .
#
#
#
# how are things going ?
#
#
#
# napakadali !
#
#
#
# what the most fast way to get there ?
#
#
#
# well , how long will it be ?
#
#
#
# you the seats 25a and 25b .
#
#
#
# i want something color white .
#
#
#
# i would like to open the window , if you do not mind .
#
#
#
# some game are there in a match ?
#
#
#
# i need a little antifreeze .
#
#
#
# very you cold in the huahin on winter ?
#
#
#
# sorry , this is not your seat
#
#
#
# how many pieces like to check in ?
#
#
#
# what is the value to go to pattaya ?
#
#
#
# am feeling much better .
#
#
#
# hope sakot in your taste all .
#
#
#
# varied ? the fare is the according to the distance ?
#
#
#
# you can get off at the next station and find a hospital there .
#
#
#
# i am on my way to the sydney .
#
#
#
# i have never i have in the first class . very it napakamahal .
#
#
#
# some tablets prefer ?
#
#
#
# what size of your waist ?
#
#
#
# you accept plastic ?
#
#
#
# i am afraid that these dishes are you have made a mistake .
#
#
#
# may i pansamantalang pamalagian the dampang it ?
#
#
#
# if there you a basketball match , i am too .
#
#
#
# waiting us are doing in the dance hall sina mr. li , mrs. chen and mr. wu .
#
#
#
# is your bill , sir .
#
#
#
# can you cheaper is the price a little ?
#
#
#
# may i hire the car for one day just ?
#
#
#
# i would like to sit inside .
#
#
#
# shoot i am a one and paki-install it for me .
#
#
#
# where is the sukhumwit skytrain station ?
#
#
#
# can you tell me if there is a flight to bangkok ?
#
#
#
# i will pay with cash .
#
#
#
# we do not will of any strong for them .
#
#
#
# always like to it will take to clear some driver the speed limit are corner .
#
#
#
# can i also have your name and number of room , please ?
#
#
#
# how you usually ginugugol are your saturday and week ?
#
#
#
# a slowly train . the second is the one that that . better wait for eleven-five from here . fast train . the second is the one that it .
#
#
#
# how much does it cost per tent ?
#
#
#
# do you go are a concert ?
#
#
#
# , please i would like a bag
#
#
#
# that is good .
#
#
#
# let biyakin i for you . it is six hundred and apatnaput
#
# /bin/sh: 2: Syntax error: Unterminated quoted string
#
# i would like to send a sertipikadong letter to china .
#
#
#
# please wait a minute , i will get a apc for you .
#
#
#
# i want to make a long distance call to chicago , u.
#
#
#
# how many pieces of luggage do you have ?
#
#
#
# called are the this chinese dumplings please mix a little soy sauce and sesame oil on this plate and dip them into it before eating .
#
#
#
# wonder to change my car for more new model .
#
#
#
# you come here often ?
#
#
#
# how much is the ticket to chonburi ?
#
#
#
# i am looking for a black shoes for my daughter . going he in a that night party .
#
#
#
# where would you prefer to sit ?
#
#
#
# i do not like the chocolate . magkakape only me , please .
#
#
#
# is there still any advance ticket of " inception " ?
#
#
#
# with makapagtuturo ? me ?
#
#
#
# there must be a mistake ; that is not mine .
#
#
#
# would you care for anything else except whole
#
#
#
# front desk . california hotel . can i help you ?
#
#
#
# can you stand close to flowers of tulip ?
#
#
#
# is quite convenient to travel by bus ?
#
#
#
# i am sorry , i do not know taken . this seat .
#
#
#
# a la carte
#
#
#
# what are scenic spots the you visited ?
#
#
#
# about 200 baht it for a express .
#
#
#
# would you have a sightseeing on the way to p. ?
#
#
#
# more than 1.1. meters in your children , one is less than 1.1 meters one .
#
#
#
# where is the table at cashier ?
#
#
#
# you sure in right way we are ?
#
#
#
# dial 9 first . after dial the number you want to get off at . call .
#
#
#
# i think we need pull evening's show the canoe , humataw a corridor to tagusan in the matinik to brush , and carry the canoe around in the streams everywhere lower of bridge .
#
#
#
# do you know where the dressing room ?
#
#
#
# how much does it cost to get to the forty-second street ?
#
#
#
# how long will it be ?
#
#
#
# welcome .
#
#
#
# i am sorry to say it is more delicious it if daragdagan the salt .
#
#
#
# he say to she's important shall do and need to reach you right away . and asked he call you he going back you .
#
#
#
# i do not know what i feel if pitching and rolyoing ship is really wonderful .
#
#
#
# right that , thank you .
#
#
#
# rocks , please .
#
#
#
# what time does it start ?
#
#
#
# i have seen it about 15 year ago a little i work in the new york .
#
#
#
# yes , i think so , too .
#
#
#
# included with the service .
#
#
#
# what is your natuklasan about to the fare a taxi ?
#
#
#
# what kind of dessert do you have ?
#
#
#
# which seat you prefer , one window seat or a aisle seat ?
#
#
#
# i will show you while was driving you .
#
#
#
# we will have a better idea after us it to see , do not you ?
#
#
#
# he said delayed is his party , and makikipagkita he you know over the phone as 1 oclock
#
# /bin/sh: 2: Syntax error: Unterminated quoted string
#
# nag-iiba-iba the exact time from a train in another train .
#
#
#
# what is the minimum weather i can rent a car ?
#
#
#
# what time does the restaurant ?
#
#
#
# very much i that .
#
#
#
# 9 : 15 departure time .
#
#
#
# should there you at set off at seven .
#
#
#
# please do not get off the train until stop it .
#
#
#
# babalutin i please ? it for you that ?
#
#
#
# why we have to buy tickets another round trip ?
#
#
#
# you recommend a malumanay , mean i say , a soft and could put up feel comfortable every day ?
#
#
#
# too slowly .
#
#
#
# i would like iced tea milk .
# and can you bring me another michelob ?
#
#
#
# a smoking car it .
#
#
#
# what style do you like best ?
#
#
#
# na-short it has a change am i
#
#
#
# please enjoy your meal .
#
#
#
# i wish you of happy birthday , sir .
#
#
#
# i do not know .
#
#
#
# very popular the qingdao beer in the our guests .
#
#
#
# help you to get the things down in the train .
#
#
#
# vinegar
#
#
#
# when does it start ?
#
#
#
# sorry . cannot i do not you have understood what i .
#
#
#
# really to imported wine will go better than domestic?
#
#
#
# and shall i put the code number of the this hotel in case they like send a fax to you ?
#
#
#
# can or i have fill in to your charge ?
#
#
#
# if we do not forgotten the food but like to eating later the food , we can asked for a doggie bag in the waiter .
#
#
#
# very good .
#
#
#
# according to our are tala , for a double room your reservation for two nights .
#
#
#
# where now i go ?
#
#
#
# we should go out on the hotel in early tomorrow because we are going in the airport .
#
#
#
# please keep it .
#
#
#
# can you fix the air conditioning ?
#
#
#
# i dropped my fork .
#
#
#
# 15 minutes , humigit kumulang.
#
#
#
# how deep can can afford is to siginooin under the water ?
#
#
#
# how much is it ?
#
#
#
# but nakakasulyap you to the arkitektura nor nash by visit the are maharlikang kabalyerisa in the buckingham palace road .
#
#
#
# should i get off at the next stop ?
#
#
#
# what can i do for you ?
#
#
#
# tell me the something about here .
#
#
#
# which places do you think visit i on the way to ... ?
#
#
#
# you can hold is the fee the bill until decide hang leave if you would like .
#
#
#
# how long is the winter england ?
#
#
#
# could you bring the bill me , please ?
#
#
#
# i need a higaan .
#
#
#
# right on !
#
#
#
# do you need a receipt for that ?
#
#
#
# we look forward to see you at noon . welcome to guangzhou restaurant .
#
#
#
# how can i go there by train ?
#
#
#
# there deretsong train to that place ?
#
#
#
# after to take the medicine your nireseta me , i think i almost no is fever .
#
#
#
# nakararamdam i am a pain when drink am i something cool .
#
#
#
# where is the dining room ?
#
#
#
# fried rice with squid
#
#
#
# you are mistaken .
#
#
#
# number 8 your dessert and item 9 are the cigarettes .
#
#
#
# small the next estayon .
#
#
#
# cannot open of your overhead light the compartment button .
#
#
#
# the flight begin boarding about 6 : 40 p.m. to gate 23 .
#
#
#
# need to speak to the my abogado .
#
#
#
# where do i have to get off for zoo ?
#
#
#
# it is about ?
#
#
#
# i would like it black .
#
#
#
# certainly .
#
#
#
# he said there is some issue of newsweek .
#
#
#
# was driving we straight to the hotel , the lake view garden hotel .
#
#
#
# i would like to mag-apply a library card .
#
#
#
# you mind pagsarado i the window ?
#
#
#
# how much luggage can i take ?
#
#
#
# some game are there in a match ?
#
#
#
# what can i do for you , mr. brown ?
#
#
#
# you may get a connecting flight .
#
#
#
# it all started the day before yesterday .
#
#
#
# it does not fit .
#
#
#
# i want something color yellow .
#
#
#
# white coffee , please .
#
#
#
# it is . it is a camera and a video camera for own use .
#
#
#
# another ticket , please .
#
#
#
# be am economy class . going to take a trip he alone .
#
#
#
# you accept credit cards ?
#
#
#
# where is the escalator ?
#
#
#
# have you audio guide ?
#
#
#
# this is the fastest way .
#
#
#
# there excess weight , do not you ?
#
#
#
# nanghihina i am .
#
#
#
# bumangga your red car in the black track .
#
#
#
# how long do you it be doing work that would require ?
#
#
#
# labag it in the regulations the customs .
#
#
#
# spicy mince chicken salad
#
#
#
# there is no hot water .
#
#
#
# i am glad you enjoyed it .
#
#
#
# should to try the ointment is .
#
#
#
# plenty of still us in above .
#
#
#
# do you have a room with a bathroom ?
#
#
#
# i want to see …
#
#
#
# we hope to welcome you again .
#
#
#
# call me .
#
#
#
# would you like a table near the window ?
#
#
#
# is there still any special there ?
#
#
#
# could you go to band here on the showcase is it ?
#
#
#
# can we stay in the phayao a little few days ?
#
#
#
# i hope it is not serious .
#
#
#
# yes . there telephone all our room .
#
#
#
# sorry ! occupied i am a foxtrot it .
#
#
#
# there is a vacant berth because i have got a a nagkansela it few minutes just ago .
#
#
#
# there telephone kiosk at the station ?
#
#
#
# how often do you usually go to the movie in the a month ?
#
#
#
# non-smoking taxi it .
#
#
#
# appreciate i your help
#
#
#
# what is the feel you ?
#
#
#
# yes , please .
#
#
#
# home i wait for you at ika-kalahati pagkaraan set off at seven .
#
#
#
# hahanapin i my seat .
#
#
#
# see .
#
#
#
# the washroom is in the middle of train . the second is the one that buffet car .
#
#
#
# makapaglalaro i a tennis this afternoon ?
#
#
#
# oh , it you that , shirley ?
#
#
#
# could you please repeat is the price , please ?
#
#
#
# ok you drink the water ?
#
#
#
# not you to necessary . you can also use the ticket of the train .
#
#
#
# where is the subway station ?
#
#
#
# no people makakagawa anything as it .
#
#
#
# this way , please . waiting outside the car .
#
#
#
# may i see the menu of dessert ?
#
#
#
# oh , i feel just make you have with you which is just nanakawan it feels really nice on the kasagsagan of the day .
#
#
#
# i pay by cash .
#
#
#
# what is the fax number ?
#
#
#
# how frequently do i need to take the medicine ?
#
#
#
# where can i send a cable ?
#
#
#
# please ready the things in the disembarkation .
#
#
#
# i am here to check in for flight to l.a.
#
#
#
# i will show you where it .
#
#
#
# can we join ?
#
#
#
# i wonder if for whose it binibili ?
#
#
#
# it depends on whether payag are the mag-ookupa to trading are upan to you .
#
#
#
# i would like a bigger room .
#
#
#
# where is the closest post office ?
#
#
#
# what time ?
#
#
#
# yes , i will the its of my best .
#
#
#
# nakapagtataka it .
#
#
#
# may i have your name , sir ?
#
#
#
# one economy class seat , that right ?
#
#
#
# you could sit wherever you man .
#
#
#
# can you have it murahan else ?
#
#
#
# oh , i am so sorry , sir .
#
#
#
# malutong catfish salad with is raw mango
#
#
#
# i have never seen such performance , but will have to be explain you me what the been going on to the stage .
#
#
#
# how about if magpunta we can go on a dance .
#
#
#
# when is the there is going to boxing ?
#
#
#
# what is the total weight ?
#
#
#
# have only cold water
#
#
#
# with panoramic cellar really you .
#
#
#
# we do not need a menu . in end still we only first party of convention .
#
#
#
# i told you i wanted medium .
#
#
#
# oh , it is easy .
#
#
#
# forgot you our drinks ?
#
#
#
# what should i do ?
#
#
#
# your beer , sir .
#
#
#
# with ship you naglalayag to phuket next week ?
#
#
#
# how about the paglilinis the bathroom little ?
#
#
#
# i would like a cheaper room .
#
#
#
# how long we was driving ?
#
#
#
# hiniwang pork and soup of the radish soup with pulbos of pepper . sichuan style .
#
#
#
# actually , could just enjoy the pinahamahusay to front of palace , the long garden front of nash , least naimbitahan in one of the are party in the garden his kamahalan .
#
#
#
# in the nan shan dining room to the first floor is the banquet .
#
#
#
# i would like to make an appointment for physical check-up .
#
#
#
# in length ? of route the huahin ?
#
#
#
# certainly , sir .
#
#
#
# that is good . can i reserve a seat ?
#
#
#
# please please keep an eye on more maigi are your important things .
#
#
#
# we will have a whole buto that
#
#
#
# now , can i pay by travellers
#
# /bin/sh: 2: Syntax error: Unterminated quoted string
#
# get are a spare parts here ?
#
#
#
# very it is too much .
#
#
#
# there is a season ticket is ann because time when he of train to work every day .
#
#
#
# how is the that night life in the guangzhou , mike ?
#
#
#
# in what drinks you like to start out ?
#
#
#
# can i have your number of room when , please ?
#
#
#
# after a sightseeing i will go back to the taiwan .
#
#
#
# we reserved a table for my birthday tonight .
#
#
#
# how long are you staying here ?
#
#
#
# i do not like travelling by ship .
#
#
#
# where can i take you today ?
#
#
#
# is there a socket in my room for my electric shaver ?
#
#
#
# like to get a berth , because i will a long journey .
#
#
#
# with something wrong with brake does i need to stop for a inspeksyon .
#
#
#
# think you i will be waiting a long time for pagsang-ayon ?
#
#
#
# could you also check the tire pressure ?
#
#
#
# please tell me where to get off .
#
#
#
# things it is not mine .
#
#
#
# where is the best beach ?
#
#
#
# is quite convenient are the bus our city .
#
#
#
# have only five minutes left . let us hurry up .
#
#
#
# i would like some postcards .
#
#
#
# this would we some recent particular and depositong five-pound .
#
#
#
# is there unlimited mileage ?
#
#
#
# sorry , complete nabook for friday .
# probably an not , but it is the pinakamalaki .
#
#
#
# i like playing bridge .
#
#
#
# is already reserved all the seats into this compartment , shall we ?
#
#
#
# you can push the seat-recliner button in the armrest for rest .
#
#
#
# what do you suggest ?
#
#
#
# land we in huahin instead of in beijing
#
#
#
# i have a bad headache .
#
#
#
# where can i get a postage ?
#
#
#
# i would like a bottle of white wine .
#
#
#
# take this bill .
#
#
#
# i need to get to 10th street in the 7th avenue . i am not sure where do change trains .
#
#
#
# then with two tuna sandwiches and a large pot of coffee .
#
#
#
# take a little period to suriin your luggage and check it on your form .
#
#
#
# if you ’ re going out just to buy some small things , do not bring along your valuables will be with you am afraid to mawala .
#
#
#
# i would like a cashmere to overcoat a man .
#
#
#
# how about this one ?
#
#
#
# when is the check-out ?
#
#
#
# i would like to send a registered letter .
#
#
#
# let me know when turn .
#
#
#
# okay .
#
#
#
# certainly , maam
#
# /bin/sh: 2: Syntax error: Unterminated quoted string
#
# anything more ?
#
#
#
# can you call a doctor , please ?
#
#
#
# you sure there is shrimp inside ?
#
#
#
# and i would like also we dekorasyonan the room are a parol and has ribbon .
#
#
#
# i cannot eat beef .
#
#
#
# is that so ?
#
#
#
# have you are a brochure it have english
#
#
#
# i would like to cancel this ticket is .
#
#
#
# what can i show you ?
#
#
#
# no , thanks .
#
#
#
# could i have … ?
#
#
#
# something is wrong with camera .
#
#
#
# would you please tell me if where can i exchange foreign currency ?
#
#
#
# wonderful are the programs . this how many in their are a medalyang gold in the sari-saring kilalang international contest in the acrobats , and what is more , they as to france , hungary , rusya and ltalya .
#
#
#
# ground pork omelet
#
#
#
# let us go .
#
#
#
# c baht altogether .
#
#
#
# thanks for your good service .
#
#
#
# can you sumulat in the aplikasyong this , please ?
#
#
#
# fly is plane
#
#
#
# how much is the tokens ?
#
#
#
# i am very sorry to clumsiness .
#
#
#
# do you have any are seats in the student rate ?
#
#
#
# do you want something to drink ?
#
#
#
# we should be careful , because mayelo the road ahead .
#
#
#
# how long is the flight ?
#
#
#
# exercise you the states ?
#
#
#
# where is the zoo ?
#
#
#
# weather for pleasure and mamahinga .
#
#
#
# which train offer the quickest service from huahin to chiangmai ?
#
#
#
# certainly , that is fine .
#
#
#
# let me give you a hand .
#
#
#
# can please tell my how to get of zoo ?
#
#
#
# sorry , it is raining outside .
#
#
#
# i will hang the window for you .
#
#
#
# can i have a seat in the window ?
#
#
#
# agenda it arrive for d minutes .
#
#
#
# ipinapakita of polyeta a hotel you there is some tennis court in your hotel .
#
#
#
# fine that . rest at the waiting-room .
#
#
#
# can you get a taxi for me in advance ?
#
#
#
# included with , i is david , the my wife .
#
#
#
# that all is his said ?
#
#
#
# how please take that seat so that you can have pay ?
#
#
#
# rather i am in a hurry . will it be long ?
#
#
#
# a lovely day !
#
#
#
# would you anything bigger ?
#
#
#
# yes , that is right .
#
#
#
# you free this afternoon , are from 3 until 4 ?
#
#
#
# no of course i maalala .
#
#
#
# when magsisimulang magpasakay the flight
#
#
#
# sounds is great before .
#
#
#
# all right , let us call it a day .
#
#
#
# what is the limit in the mileage ?
#
#
#
# give you select one that goes well an itemized bill ?
#
#
#
# all my personal effects .
#
#
#
# we have a variety of sodas drinks and fruit juice .
#
#
#
# you know how much is it ?
#
#
#
# twenty kilograms the limit the weight for articles charge .
#
#
#
# maaakses it of disabled ?
#
#
#
# easy just the path inconvenient ?
#
#
#
# 36 baht the main course and not 33 baht .
#
#
#
# water is leaking from ceiling the bathroom . could you send some please in my room right away ?
#
#
#
# i would like to reserve a table for for this evening at 10 oclock
#
# /bin/sh: 2: Syntax error: Unterminated quoted string
#
# i am locked out of the room .
#
#
#
# i would like to have the completely insurance . how much does it cost per day to rent a car for ?
#
#
#
# steamed sticky rice and coconut
#
#
#
# have you snack bar in the hotel ?
#
#
#
# how still far is it ?
#
#
#
# actually , i also want make some journey .
#
#
#
# mr. bush , it is the your seat . sit down here , please .
#
#
#
# have you silk thai here ?
#
#
#
# why is that often ?
#
#
#
# you know what the luggage allowance ?
#
#
#
# you can buy the like in the store of ceramic .
#
#
#
# will check to see you it into the bonded storage room and will a receipt .
#
#
#
# nilagay the time some time back .
#
#
#
# please show me the way to the hospital .
#
#
#
# can you like to join me and ipadebelop it ?
#
#
#
# is there any what bus you does this path go to that direction ?
#
#
#
# i would like to cancel my trip to japan .
#
#
#
# not , i went with is jane .
#
#
#
# i am afraid i am not they found in the restaurant . can you call the lost and found department on extension 2157 , please ?
#
#
#
# excuse me , i have lost my wrist-watch .
#
#
#
# would you like to take order now ?
#
#
#
# executive suites only there is now .
#
#
#
# how is it , sir ?
#
#
#
# let us split the checks .
#
#
#
# what are pagpipilian for the soup ?
#
#
#
# where i can get a subway map ?
#
#
#
# could you check if there missing ?
#
#
#
# i will stay here a little 15 day .
#
#
#
# ' the moon reflected in ' the twin ponds . one overeating erhu solo . butterfly lovers . one overeating violin concerto . a party are you going to have and how many other popular pambayang music and song .
#
#
#
# how much luggage is allowed i have take ?
#
#
#
# good afternoon , ladies and gentlemen .
#
#
#
# there are too much salt in meat .
#
#
#
# i think you made a mistake .
#
#
#
# a good trip !
#
#
#
# i am afraid i mahulog going to be on the ground are the acrobats .
#
#
#
# is there parking lot nearby ?
#
#
#
# how you sold are those ?
#
#
#
# i am not drink at all .
#
#
#
# i am not responsible for here .
#
#
#
# i am lost .
#
#
#
# here are your ticket .
#
#
#
# i have made up my mind you , gentlemen ?
#
#
#
# went it is . it is a tired old pangturistang landscape .
#
#
#
# want to buy a ticket , economy class .
#
#
#
# napakainteresante a book ?
#
#
#
# could you pass me the salt please ?
#
#
#
# it is . it is a satellite to tv program .
#
#
#
# i would like a shigaanch and water
#
#
#
# can i buy a ticket of berth in the train ?
#
#
#
# of course .
#
#
#
# am i your be local guide the weather of your stay in phayao .
#
#
#
# all right , i shall .
#
#
#
# you accept travelers
#
# /bin/sh: 2: Syntax error: Unterminated quoted string
#
# do not worry , mapapa-endorso you then it to get on in the train .
#
#
#
# you should go to gate 10 to take your plane
#
#
#
# i will be at a guided tour in the with city of mountain .
#
#
#
# i prefer also is a will it be an evening performance .
#
#
#
# better you arrive at the airport before 8 : 00 .
#
#
#
# this is my treat. it is my treat this time the bill .
#
#
#
# there is a komentaryo about it in program . read you if you would like .
#
#
#
# i would like to makapanood thai kung-fu
#
#
#
# how long for to get there ?
#
#
#
# what time will we arrive at hat yai ?
#
#
#
# please you enjoy your breakfast .
#
#
#
# think i are you tired after the long journey .
#
#
#
# what is the have you got on the menu now ?
#
#
#
# i have got a sore throat .
#
#
#
# i would like to rent a water ski .
#
#
#
# sorry , sir . could you check it again ?
#
#
#
# but you will have to check out at that time , or need we will have to give bill for another evening .
#
#
#
# think i no story it .
#
#
#
# dalawamput
#
# /bin/sh: 2: Syntax error: Unterminated quoted string
#
# where is the toy store ?
#
#
#
# or , i see .
#
#
#
# could you show me your identity card card ?
#
#
#
# not so bad .
#
#
#
# i am interested in are perfume .
#
#
#
# oh , is there anything else that . i need to send a fax in the usa . it is the main message .
#
#
#
# 10 baht the charge for first three kilometers and 1.6 baht for each additional kilometers .
#
#
#
# miss , where is the toilet ?
#
#
#
# what flowers it ?
#
#
#
# not matalas this knife is .
#
#
#
# please give me a three return ticket to lop buri 6 p.m.
#
#
#
# kayumanggi and katamtamang size .
#
#
#
# will be fine we if there is no traffic jam .
#
#
#
# no. 28 .
#
#
#
# i do not exact nalalaman , but i am sure i have even 300 kind . they can igrupo at four are kategorya : are stringed instrument , plucked instrument , percussion instrument and wind instrument .
#
#
#
# wonton
#
#
#
# there fastest mode of transport into town ?
#
#
#
# not you with wrong in the bill ?
#
#
#
# where i makapagpapadala of kable ?
#
#
#
# what is the famous are historic place in bangkok ?
#
#
#
# well , it is so beautiful .
#
#
#
# because linda used the engine reverse-thrust sisteme to pabagalin the plane
#
#
#
# but arrives the express train at your destination snack , while arrives the fast through train there in the morning .
# 10 p.m. our last order . would you mind having a arrive before that , please ?
#
#
#
# you may go straight over there by trains .
#
#
#
# would you like some dessert now ?
#
#
#
# for wine that , sir .
#
#
#
# where are the salbabida ?
#
#
#
# in transit i am .
#
#
#
# there is an electric fan in the compartment . open it , please .
#
#
#
# malabo at the a late to kinunan .
#
#
#
# traffic has completely stopped .
#
#
#
# would you like it now or after your dinner ?
#
#
#
# well , i would like to try the rehiyonal food .
#
#
#
# can you tell me if how get over there ?
#
#
#
# what is the time now ?
#
#
#
# all right . i would like to settle my bill by credit card .
#
#
#
# i am a foreign estudyanteng nag-aaral in thailand .
#
#
#
# how you , mark ?
#
#
#
# binigyan i am a ginookong it is a understanding in the culture ? chinese one .
#
#
#
# i have reserved a single room for mayo ika-3. but will me the a friend , so i prefer to change the reservation from single room to a double room .
#
#
#
# your name , please .
#
#
#
# went i am glad now .
#
#
#
# here is your luggage checks . it is the your boarding pass . you going it while way to the ride a plane
#
#
#
# mahangin now .
#
#
#
# are store there not nagbubuwis ?
#
#
#
# can i mag-stop over ?
#
#
#
# not all . ipinagbawal the pagluwas paintings are before the qing dynasty .
#
#
#
# which do you prefer .
#
#
#
# when do you want to travel ?
#
#
#
# please fill in the this form .
#
#
#
# called are the this chinese dumplings
#
#
#
# here is your soup of the three delicacies .
#
#
#
# when will the match of golf ?
#
#
#
# did i receive any letter ?
#
#
#
# too to like the chinese food .
#
#
#
# i would like to make some sightseeing china .
#
#
#
# do we security insurance for all ?
#
#
#
# a toy us is it open , ok ?
#
#
#
# we look forward to to having you with us tonight .
#
#
#
# ready . cheers .
#
#
#
# have you elevator ?
#
#
#
# when should i be check in ?
#
#
#
# i do not understand mean that .
#
#
#
# yes , cannot be faster that .
#
#
#
# agenda you arrive at e.
#
#
#
# not you think you be faster it ?
#
#
#
# really it looks fascinating .
#
#
#
# here you are , sir you are . it comes to pitong way and siyamnaput
#
# /bin/sh: 2: Syntax error: Unterminated quoted string
#
# could you wait until after we take off ?
#
#
#
# is there anything cheaper ?
#
#
#
# i would like a memory card .
#
#
#
# take me to the hospital .
#
#
#
# here is the baggage claim .
#
#
#
# but you must pay a dagdag.
#
#
#
# if you are interested in the city , beef would you like to tour it by car .
#
#
#
# two week lampas in the taning these books . sorry , i have to ask you to pay a multa .
#
#
#
# when does the dining car open for dinner ?
#
#
#
# could you wait still a little , please ?
#
#
#
# here is your key room .
#
#
#
# can we asked for some snacks ?
#
#
#
# bring we at the park tram station .
#
#
#
# now .
#
#
#
# where you exact have used up your passport in the store ?
#
#
#
# where is the bridge ?
#
#
#
# maaakses it of handicapped ?
#
#
#
# this way , please .
#
#
#
# may i help you with your baggage ?
#
#
#
# can you write your name and room number and please sign here ? we will send up originally so does the other 30 copies in your room again .
#
#
#
# there you will have to special diet ?
#
#
#
# napakalapit before here .
#
#
#
# flying he over san francisco . do you know that , that right ?
#
#
#
# here is the $ 70 . which would you keep the change .
#
#
#
# i will have a look in the timetable for you .
#
#
#
# sorry . i am afraid it is a bit have been sold out . our barbecued suckling pigs .
#
#
#
# that sounds good . how you , lisa ?
#
#
#
# with binuhat you or with ginalaw heavy ?
#
#
#
# can i help you ?
#
#
#
# there is a police . let us ask him the way .
#
#
#
# do not think much of it excess like , may i have a change of order ?
#
#
#
# ok , give me a ticket for train 11 : 40 .
#
#
#
# you have completed is transfer formalities ?
#
#
#
# a nice place it .
#
#
#
# nagpaabot you a lot of invitation ?
#
#
#
# tomorrow the party daughter's birthday my daughter and we are going to have a party in the hotel .
#
#
#
# will bring them you to your new table .
#
#
#
# in the passengers to c , please get ready in the disembarkation .
#
#
#
# think i with a bad cold , i and now a little feverish .
#
#
#
# would you magpaligsahan ?
#
#
#
# how much is the rate per day ?
#
#
#
# sorry , reserved this berth is occupied .
#
#
#
# no namang specialties .
#
#
#
# eaten to nor mr. norman is his last food . think he else it in the his ordered .
#
#
#
# what stop is this ?
#
#
#
# i will check .
#
#
#
# can i try it on ?
#
#
#
# could you come here ?
#
#
#
# in the room when of konsultasyon .
#
#
#
# how much are you selling the fish it ?
#
#
#
# oh , i see . thank you .
#
#
#
# i heard excess good there .
#
#
#
# where get food ?
#
#
#
# can i change my upper berth for a lower ?
#
#
#
# nabasag i is that lamp .
#
#
#
# i would like an aisle seat .
#
#
#
# please let us stand in a line .
#
#
#
# is there anything the matter ?
#
#
#
# the box a wonderful land yellowstone to naka-intriga are isipan people of , inantig them , and nag-bigay-inspirasyon on them .
#
#
#
# there a car accident in the main street .
#
#
#
# what brand of beer prefer ?
#
#
#
# i hope not be a problem pagkakaroon of two or three room when in a week .
#
#
#
# is too hot the dish it .
#
#
#
# will the traffic be heavy ?
#
#
#
# we look forward to to having you with us tonight .
#
#
#
# sounds low you to the gasoline .
#
#
#
# we have both .
#
#
#
# have a nice stay .
#
#
#
# may i see some photos of the are hair-do ?
#
#
#
# where can i find some information about here ?
#
#
#
# lumampas the this letter in the karampatang weight limit .
#
#
#
# all right .
#
#
#
# thank you for paghintay , sir .
#
#
#
# estimated about a time .
#
#
#
# as soon as me to the airport naghanap i am a money changer counter .
#
#
#
# there is a charge for alcoholic beverages in economy class .
#
#
#
# where is breakfast served ?
#
#
#
# is it possible for me to make a buy a monthly or weekly pass to save some money ?
#
#
#
# have you antifreeze stored ?
#
#
#
# i am is david wong , a friend nor mary .
#
#
#
# what is the departure time of ship to patras ?
#
#
#
# i would like to a car this car for business .
#
#
#
# i wonder if i it is mine .
#
#
#
# so to work if when do i would like .
#
#
#
# may i have a look at your passport ?
#
#
#
# who you think is will win of championship tonight years ?
#
#
#
# could you magmunkahi a sightseeing ?
#
#
#
# i would like spicy it . can you add the garlic ?
#
#
#
# have sunstroke .
#
#
#
# let me change it at another one for you .
#
#
#
# why ?
#
#
#
# should i call an ambulance ?
#
#
#
# with smaller you have money ?
#
#
#
# ask him to call me , please .
#
#
#
# how much is the to call back ?
#
#
#
# where to , miss ?
#
#
#
# you prefer a table in the raft ?
#
#
#
# office dr. anderson .
#
#
#
# i would like to call the family .
#
#
#
# i am going to the london .
#
#
#
# exact change , please .
#
#
#
# when will the final of football ?
#
#
#
# can i get a telegram form ?
#
#
#
# i have brought of books for you .
#
#
#
# where is the emergency exit ?
#
#
#
# cannot extend the berth ticket , but you can apply for refund of it .
#
#
#
# where the monument of gera ?
#
#
#
# the check , please .
#
#
#
# could i take your order now ?
#
#
#
# have you transformer for electric razor of my wife ?
#
#
#
# makapagpapayo you … ?
#
#
#
# put your cup in the side table by the window .
#
#
#
# i am not sure . Mga 6 : 30 p.m.
#
#
#
# i want something color red .
#
#
#
# where is the this river ?
#
#
#
# send a people to help me , please .
#
#
#
# go this way the train is about to pass over the many important are point .
#
#
#
# please give them the your name and number of rehistrasyon arrival you to collect your ticket .
#
#
#
# thank you for waiting .
#
#
#
# i would like of platinum .
#
#
#
# i see natutulog your friend .
#
#
#
# everything is here .
#
#
#
# take the this bill .
#
#
#
# and also sound in my are ears .
#
#
#
# i want to change my reservation .
#
#
#
# are there traffic jam chonburi ?
#
#
#
# please signature here .
#
#
#
# no popular of day in winter time .
#
#
#
# now , how at the another other half ?
#
#
#
# what would you recommend order we ?
#
#
#
# please go back to the your coach .
#
#
#
# good morning , mr. lawson .
#
#
#
# when is the pinakahuli i can leave ?
#
#
#
# can i have a ticket in the berth in the train ?
#
#
#
# i would like to fly to san francisco on sunday , the 5th .
#
#
#
# . which would you prefer , beef or chicken ?
#
#
#
# how much is the fare the extra luggage ?
#
#
#
# i suggest that you buy a commuter pass .
#
#
#
# i am calling to put a air reservation for mr. thomas kant .
#
#
#
# after how about you nag-aaral ?
#
#
#
# what is the matter with you ?
#
#
#
# napakahangin now ?
#
#
#
# what is on at the grand cinema now ?
#
#
#
# this is our last service for coffee .
#
#
#
# sounds that is right .
# naakit i am very much . a great acting with a moment to at i have missing in the myself here .
#
#
#
# you can get the bus is no. 16 .
#
#
#
# very you maunawain .
#
#
#
# face overeating good .
#
#
#
# in me this in the smoking section i am .
#
#
#
# can you bring me some menu ?
#
#
#
# can you fix the heat ?
#
#
#
# all right .
#
#
#
# please put your name , address and nationality .
#
#
#
# you tell my where get a ticket for the train to lat krabang ?
#
#
#
# i would like a smaller a little .
#
#
#
# can you tell me the hire charge for for 1100s
#
# /bin/sh: 2: Syntax error: Unterminated quoted string
#
# you going above ?
#
#
#
# is there anything else that you least it ?
#
#
#
# i will go back to the next days .
#
#
#
# i would like a glass coconut water .
#
#
#
# me , too . it
#
#
#
# excess i feel a little sick in in the way tinuring you i am .
#
#
#
# the flight to boston .
#
#
#
# do you serve soft drinks ?
#
#
#
# owe , please .
#
#
#
# i feel like going to the karaoke bar .
#
#
#
# it is not . the second is the one that stops at to prae .
#
#
#
# change to the east croydon .
#
#
#
# where should i change the train to tumungo to chonburi ?
#
#
#
# have allergic reaction .
#
#
#
# would you subukin the dance is it ?
#
#
#
# i would like a glass iced tea .
#
#
#
# can i be of any assistance ?
#
#
#
# i am so glad you like it , betty .
#
#
#
# just put them in the table over there , please .
#
#
#
# delicious is just what i mushroom omelette .
#
#
#
# here .
#
#
#
# now , what can i do for you , sir ?
#
#
#
# please book me a table for five people .
#
#
#
# glad also i see you .
#
#
#
# you prefer to sit outside ?
#
#
#
# i am very sorry to say that you to no through train from here to a.
#
#
#
# you been over there ?
#
#
#
# some day do you want to a car this car ?
#
#
#
# think i naningil they two times for the same thing .
#
#
#
# i am allergic to are antibiotics .
#
#
#
# perhaps tired are you tired after a long journey .
#
#
#
# yes .
#
#
#
# i shall this . just a moment , please . here is your bill .
#
#
#
# it is just like katutubong club with thai music , do not you ?
#
#
#
# how much should i pay ?
#
#
#
# that is quite all right . would like just a wife i try the how many in popular , imported chinese wine .
#
#
#
# on the bus . kinokolekta the conductor are the charge .
#
#
#
# can i rent are equipment pang-isports ?
#
#
#
# what did palang said to bababaan you ?
#
#
#
# i would like to reserve a table for 7 : 00 , please .
#
#
#
# can i have the big size , please ?
#
#
#
# can you give me for a cough ?
#
#
#
# bistro
#
#
#
# there multa if i will not take it on time ?
#
#
#
# or a lot , surely indeed makapanindig-balahibo it !
#
#
#
# should first we be sure to no any wrong with the bike .
#
#
#
# here is all in the group ?
#
#
#
# tomorrow is library on sundays ?
#
#
#
# it is not allowed of my company .
#
#
#
# can you help me ?
#
#
#
# board you on the plane ?
#
#
#
# i need will change all my money a little minsanan ?
#
#
#
# which platform tatayo the train from huahin ?
#
#
#
# may wait in the a minute ?
#
#
#
# first , second or third kinds ?
#
#
#
# i have lost a many blood .
#
#
#
# you can put your coat and small things on the rack over your head and your bag at your feet .
#
#
#
# what a music !
#
#
#
# usually i swim twice in the a week .
#
#
#
# full it .
#
#
#
# maaraw and partly it is cloudy .
#
#
#
# good evening .
#
#
#
# what type of medium-sized to car do you have ?
#
#
#
# you should better get off to take another taxi .
#
#
#
# with cream and sugar ?
#
#
#
# do you like this one ?
#
#
#
# please bring me a toothpicks .
#
#
#
# we need to wait .
#
#
#
# with sitting on this seat
#
#
#
# welcome .
#
#
#
# i have seen it quite a few years ago .
#
#
#
# where should i take of train to sa kaeo ?
#
#
#
# it rains now outside .
#
#
#
# i need to go to guangdong world trade center .
#
#
#
# just a moment , please .
#
#
#
# pakipunan the form it and return this me .
#
#
#
# i would like to have one window seat .
#
#
#
# i would like a compact car that takes good mileage .
#
#
#
# you accept travellers
#
# /bin/sh: 2: Syntax error: Unterminated quoted string
#
# with these books you in english nor … ?
#
#
#
# i would like a child's ticket for the mr. how much is it ?
#
#
#
# i am glad you like it .
#
#
#
# are not too easy parts a quiet place on the this time .
#
#
#
# here you are .
#
#
#
# how do you like the rest of the matt or gloss to pag-imprinta ?
#
#
#
# what is the shortest weather i can rent a car ?
#
#
#
# i would like a glasses .
#
#
#
# thank you for your help .
#
#
#
# i will do it for you straight away .
#
#
#
# about where the announcement ?
#
#
#
# do you have any car available ?
#
#
#
# anything else i should offer you ?
#
#
#
# why there are so many is so good to ride in kasalda ?
#
#
#
# be careful you to the paghakbang !
#
#
#
# called it
#
# how do i it pay ?
#
#
#
# who is the speaking , please ?
#
#
#
# there subway to town ?
#
#
#
# how am i be able to come at all the bus station ?
#
#
#
# small bills , please .
#
#
#
# may i have some more of water ?
#
#
#
# where can i find a are gay venue ?
#
#
#
# i am here for holiday .
#
#
#
# a economy class ticket .
#
#
#
# arrive on time is the ship ?
#
#
#
# napakalala an accident of cars !
#
#
#
# she sang a very mahimig to pambayang song , did not she ?
#
#
#
# welcome .
#
#
#
# really special are the exhibit .
#
#
#
# need a my car a changing oil .
#
#
#
# i cannot pronounce the street names road .
#
#
#
# would you to sit in the corner ?
#
#
#
# let me have a look at your in of your bag
#
#
#
# there strong beat rock and roll .
#
#
#
# be a good kuha that .
#
#
#
# for here or bring ?
#
#
#
# booked we for a table for eight .
#
#
#
# good !
#
#
#
# i need a receipt , please .
#
#
#
# can i change my seat slow for a while ?
#
#
#
# how long does it take to go to there ?
#
#
#
# there are many scenic spots on way to mr.
#
#
#
# could you get a cab for me ?
#
#
#
# napaayos it three days ago .
#
#
#
# you can maghabol of damage on counter over there .
#
#
#
# constant you just go straight . turn left you here .
#
#
#
# i would like a classic .
#
#
#
# please get me a taxi .
#
#
#
# i would like a abrelata .
#
#
#
# a lovely performance !
#
#
#
# yes , be there i am , and i have brought a friend from another school .
#
#
#
# with a limitadong have a warranty on this one just the car nor ron and he was so sick that he had to pay are a new tire
#
#
#
# with how many guests to join your table , miss .
#
#
#
# have had i am a there is too much .
#
#
#
# lilinisin you is basketball court ?
#
#
#
# going to take a trip i am a economy class .
#
#
#
# we are flying in the speed 800 kms / hr ( eight hundred kilometers every time ) and the altitude to 7,800 meter .
#
#
#
# yes , this is good .
#
#
#
# it does not seem to be that you satisfaction .
#
#
#
# you are right .
#
#
#
# can i see your a price list ?
#
#
#
# can you show me some imahe nor buddha ?
#
#
#
# white cloud restaurant on your service .
#
#
#
# be all right the corner table ?
#
#
#
# may i have a look at your money ?
#
#
#
# how many trains are there from here to to q every day .
#
#
#
# would you like to try the other menu .
#
#
#
# nakapag-ski tour you have with you which is ?
#
#
#
# are ski lift them ?
#
#
#
# punta we there now .
#
#
#
# oh , so many stuffed sold here .
#
#
#
# can you tell me the fare per night for a single room with a bath ?
#
#
#
# how much does it cost per ?
#
#
#
# some stops to huahin ?
#
#
#
# how long to get to downtown ?
#
#
#
# visit you the tower three yugto .
#
#
#
# you buy a hard seat ticket , not ?
#
#
#
# going to a journey hiking club the next months .
#
#
#
# can is one .
#
#
#
# nice day .
#
#
#
# stop the next corner , please .
#
#
#
# equipped equipment another air-condition the train .
#
#
#
# can you show me some a key ring ?
#
#
#
# please send another blanket in my room .
#
#
#
# how about hard-seat and soft-seat car ?
#
#
#
# organiko it ?
#
#
#
# want to book a first class .
#
#
#
# with temperature i am , and i feel a little sick .
#
#
#
# started still just we are .
#
#
#
# how katapang would you like it ?
#
#
#
# what is your are rate ?
#
#
#
# can you bring it right away ?
#
#
#
# i will send the ticket to you .
#
#
#
# where is the building of faculty of medicine ?
#
#
#
# now , about the are gold ornamento and jewelry are carrying you . naideklara them everything going ?
#
#
#
# i left my bag here .
#
#
#
# 918 your room number .
#
#
#
# i prefer a car aleman .
#
#
#
# here we are .
#
#
#
# there is a that night patong to charge .
#
#
#
# in your excess would better health , sir .
#
#
#
# yes , just a moment , please .
#
#
#
# give me some pictorials .
#
#
#
# we need tank . for the french , we need 14 r35s and 12 fcm36s ; for british , 19 m4cs ; for aleman , 17 pz38s .
#
#
#
# usually crowded because there is such a are really a big populasyon thailand is
#
#
#
# pepper too ?
#
#
#
# iniligtas you really day for me .
# bob ! we will have a party are a classmate tonight , would you like to go ?
#
#
#
# not .
#
#
#
# could i have it isama in my account ?
#
#
#
# where i should depart if i am transferring to number 3 bus .
#
#
#
# i have never kailanman on board the trip the air like this .
#
#
#
# how much do i owe you ?
#
#
#
# stolen my hire car .
#
#
#
# we serve black tea .
#
#
#
# can you recommend a boat trip ?
#
#
#
# i am afraid there is no before the middle day .
#
#
#
# with would you like other mainom ?
#
#
#
# patong rice
#
#
#
# that right ?
#
#
#
# you not know ?
#
#
#
# i will check it for you .
#
#
#
# two , please .
#
#
#
# it is the five baht as my tip .
#
#
#
# i would like a cheaper one . perhaps your made the states .
#
#
#
# can you give me a analgesic ?
#
#
#
# please put me as connecting flight to san francisco .
#
#
#
# yes , i have just naiinis .
#
#
#
# too to am afraid . i would like sanang allow , but see much do you measure my difficulty .
#
#
#
# i am afraid i am not i am have brought money .
#
#
#
# gumagalaw a little pabilis a little pabilis the vehicles ahead .
#
#
#
# what is the usual you like to dinner ?
#
#
#
# i would like to change my reservation .
#
#
#
# do you think it is ok to should we trying somewhere else ?
#
#
#
# only have hand 300 u.s dollars
#
#
#
# i would like to have my valuables from the safe .
#
#
#
# some stops to silom ?
#
#
#
# here is the fried beef with green pepper and onion , madam .
#
#
#
# the service is superb .
#
#
#
# when nakatakdang arrive in chicago train ?
#
#
#
# where is the magbibihis ?
#
#
#
# let us call the company a taxi , and ask for one .
#
#
#
# often you runs trains ?
#
#
#
# do you ever swim ?
#
#
#
# what ferries important cities will the train pass by ?
#
#
#
# i will pay by credit card .
#
#
#
# suitable it for 10 people gulang ?
#
#
#
# you know the international code for thailand ?
#
#
#
# what kind of material it ?
#
#
#
# are there train for there ?
#
#
#
# it is too tight in the with stomach . have a bigger one still you have any in size ?
#
#
#
# sorry , i am short on i know i about in your railway regulations .
#
#
#
# have done the bill by renminbi . if you will pay by us dollars , isasalin we the renminbi in the us dollars against exchange rate today .
#
#
#
# feel dizzy you enjoy yourself ?
#
#
#
# missing my baggage .
#
#
#
# not , no , it is not .
#
#
#
# please bring me a menu .
#
#
#
# thai dishes
#
#
#
# if would you like of any additional food , please call much do you measure just i am .
#
#
#
# what kind of perfume do you have ?
#
#
#
# a stereocopic film the
#
# can you tell me if what is the problem ?
#
#
#
# there is is whistle . is pulling out we are .
#
#
#
# fill out he , please .
#
#
#
# i am not bumibili to the first think lang.
#
#
#
# lucky i am really to get a ticket tonight .
#
#
#
# allowed the children ?
#
#
#
# if i want to get off at the saraburi , which train should i take ?
#
#
#
# i am going to need an operation ?
#
#
#
# no problem .
#
#
#
# mahapdi it .
#
#
#
# which stop the pinakamalapit post office ?
#
#
#
# margarin
#
#
#
# would you like to bring some ginger ?
#
#
#
# how he nilaro the season is it ?
#
#
#
# can you make out this prescription it for me , please ?
#
#
#
# yes , it is the first time in you for a long time . weather .
#
#
#
# when the lights of bleach , plus bleach .
#
#
#
# i would like to reserve a table for next saturday .
#
#
#
# i have been suffering in the jet lag
#
#
#
# a car with semi-cushioned seats is a hard-seat car .
#
#
#
# is far still it is a i can accept .
#
#
#
# need to i have to change trains ?
#
#
#
# be careful the cars when go out you .
#
#
#
# is it severe ?
#
#
#
# here is your bill .
#
#
#
# spicy ? the dish it ?
#
#
#
# do you have any baggage to will check to see ?
#
#
#
# here is the fare .
#
#
#
# should i taguin is my passport and money ?
#
#
#
# look , it is the famous world trade centre .
#
#
#
# where is the nearest toilet ?
#
#
#
# i do not know . let us ask the stewardess .
#
#
#
# yes , sir .
#
#
#
# how long are you tomorrow ?
#
#
#
# you cannot miss it .
#
#
#
# why you do not be seated ?
#
#
#
# what is the price for return ticket , please ?
#
#
#
# who is the punong referee of tournament inaugurated ?
#
#
#
# direct flight , is it not ?
#
#
#
# fried spring rolls
#
#
#
# cheaper buy a return ticket .
#
#
#
# i would like to see the pagkawasak .
#
#
#
# i am looking for a really that leather bag
#
#
#
# sorry , how long i cannot keep these books for ?
#
#
#
# and where are you visiting ?
#
#
#
# you can continue of your journey within this period .
#
#
#
# i have had enough . i will take now the check .
#
#
#
# come in we are .
#
#
#
# i had not expected will be excess cold here .
#
#
#
# may i clean the table , sir ?
#
#
#
# if you are going to the including is at one end of the lounge this and turn right , you can see it .
#
#
#
# i could not sleep even little last night .
#
#
#
# here is the your claim tag give it only when you to get the case .
#
#
#
# i am not late for work but i have got to a change of my clothes .
#
#
#
# let me help you with the luggage .
#
#
#
# whose song it ?
#
#
#
# too nagpapasalamat i am on you .
#
#
#
# i am going to the railway station .
#
#
#
# sounds be maaliwalas .
#
#
#
# where is the kastilyo ?
#
#
#
# naharang ? train ?
#
#
#
# sorry have been booked we for tomorrow .
#
#
#
# i will just have of dish light .
#
#
#
# how do you like the rest of the art ?
#
#
#
# i have broken my journey in the madaliang work .
#
#
#
# little more , please .
#
#
#
# how much is the one-way ticket ?
#
#
#
# please go to the caac office to mai-book your ticket on the plane
#
#
#
# what kind of food is pinagsisilbi in the train ?
#
#
#
# in the what time do you knows is the last order ?
#
#
#
# a table for four ?
#
#
#
# of course .
#
#
#
# size 40 .
#
#
#
# what is the postage here ?
#
#
#
# how deep can i dive this wet suit ?
#
#
#
# premium or regular , sir ?
#
#
#
# sorry , maam
#
# /bin/sh: 2: Syntax error: Unterminated quoted string
#
# think i should kumunsulta in the espesyalista .
#
#
#
# could you get a doctor ?
#
#
#
# speak more strong , please .
#
#
#
# oh , is terrible ! that .
#
#
#
# better luck in the pagkakatong it .
#
#
#
# i am the attendant who on this floor .
#
#
#
# my car broke down .
#
#
#
# may i ilaba my clothes ?
#
#
#
# i would like my egg hard-boiled .
#
#
#
# if can get me it is a with enough kaagahan , there good tsansa a little pag ride it feels really nice on the same train will take you .
#
#
#
# when we go to see the movie challenger ?
#
#
#
# with kalubus-lubusang pleasure , shirley .
#
#
#
# i would not the bar stool .
#
#
#
# can i pay by credit card ?
#
#
#
# what will it be altogether ?
#
#
#
# a chinese musical instrument ensemble the first things , including obra-maestra gay a little ' the night of spring flowers , river , lost and moon .
#
#
#
# follow me , please .
#
#
#
# here is the twenty dollars , keep the change .
#
#
#
# used i have pass by including way .
#
#
#
# better to carry it with me when i left with you .
#
#
#
# okay .
#
#
#
# ...
#
#
#
# i found this bartender to haluin it by the best brats a gin and vermouth .
#
#
#
# when is the next train to prae ?
#
#
#
# you ’ re going out at the exit and going to have to wait for here comes limousine to gate number five .
#
#
#
# in fact , even i am i do not know how many kinds coins have you .
#
#
#
# Pakiusap pakilaan i am the first class seat in the window .
#
#
#
# i would like a seat on the corridor .
#
#
#
# which do you prefer , upper , lower , or middle ?
#
#
#
# in end it a car .
#
#
#
# you are required to pay for excess articles .
#
#
#
# pundido else is light bulb of that lamp in the my room .
#
#
#
# thank you .
#
#
#
# emerhensya it .
#
#
#
# good morning . pleasure to meet you .
#
#
#
# i do not have much time we during this time of day put ourselves in trouble . but i would like we soup of the mais .
#
#
#
# here is our imbentaryo are a car .
#
#
#
# how about visa ?
#
#
#
# it is the toilet with a shower and a bath .
#
#
#
# na-fill out do you customs declaration form ?
#
#
#
# i have no thailand departure card . where i can get it ?
#
#
#
# how much for it ?
#
#
#
# please take me to railway station .
#
#
#
# two cars crashed into each other .
#
#
#
# you need not worry about here .
#
#
#
# which flight are you going to have ?
#
#
#
# i am visiting my kapatid boy .
#
#
#
# what can we do in our are luggage ?
#
#
#
# you tell me if where is the taxi stand ?
#
#
#
# norman , joseph norman .
#
#
#
# it is the pillow to visit in bangkok .
#
#
#
# there sleeping car is this train
#
#
#
# there a special things on the program - american popular music .
#
#
#
# with seats you are 300 baht ?
#
#
#
# i have a special pagkagusto for light music .
#
#
#
# can i be our guide you .
#
#
#
# i would like a pwestong near the window .
#
#
#
# which theatre ?
#
#
#
# i spilled my drinks .
#
#
#
# can you pack the length ?
#
#
#
# two or three days now .
#
#
#
# fried chicken
#
#
#
# have you pool for children ?
#
#
#
# you can only move to the reserved section a seat in the first class .
#
#
#
# how much is it ?
#
#
#
# is joan it ?
#
#
#
# no we direct flight to san francisco . but you can fly of pan am to l.a. and in l.a. you could take a connecting flight to san francisco .
#
#
#
# pagkakatiwalaan you .
#
#
#
# not allowed the passengers to bring some animals in a coach .
#
#
#
# can you help me ?
#
#
#
# one for trip ?
#
#
#
# do not worry .
#
#
#
# would you drink before the dinner ?
#
#
#
# there is something wrong with my car .
#
#
#
# sorry , but smoking is not allowed here .
#
#
#
# it is not serious , i hope so . i
#
#
#
# in which direction should i go to get to pattaya ?
#
#
#
# " gone with the wind " .
#
#
#
# can i help you ?
#
#
#
# which horses is your favorite in this race ?
#
#
#
# there near telegraph office ?
#
#
#
# i would like to change the order . bring me a ham steak is all .
#
#
#
# does this bus run at no. 63 each thirty minutes and here i am on more than dalawamput
#
# /bin/sh: 2: Syntax error: Unterminated quoted string
#
# need i me some pain-killer , please .
#
#
#
# watch i am a tv every day . went part of this of my life .
#
#
#
# the big one will not fit in the car .
#
#
#
# what can i offer to you ?
#
#
#
# what else are you taking ?
#
#
#
# make a right at the next corner and go straight .
#
#
#
# not you it rains now ?
#
#
#
# glad we see again .
#
#
#
# i am not arrive at the bayang until ika- 3 : 00 in the afternoon .
#
#
#
# i would like a pang-alis pain .
#
#
#
# sure did it .
#
#
#
# think i pressure is low harapang right gulong we arrive .
#
#
#
# i think i will have to taken some medicine .
#
#
#
# over there are the window of long-distance bus ticket .
#
#
#
# your pansin , please . nakapirmi now on the platform 6 is the 9 : of 34 hualumphong express .
#
#
#
# including ? the price insurance ?
#
#
#
# ipinakilala is a chinese instrumento , called the
#
# what charge for instructions ?
#
#
#
# i would like to cancel my reservation for two for for mayo 25 at 11 : 30 a.m.
#
#
#
# where it is ?
#
#
#
# i am very sorry to cannot checked your parcels as going up and down is not you still through are is it necessary to return formalities .
#
#
#
# welcome it .
#
#
#
# have you size xl stock ?
#
#
#
# i need to ask you to get out here .
#
#
#
# i use what is this medicine .
#
#
#
# what kind of luggage it ?
#
#
#
# not a less nakakaintindi a lot of english the french family it .
#
#
#
# pleasure to you enjoyed it .
#
#
#
# may i have your phone number ?
#
#
#
# bring your luggage in the your room just a moment .
#
#
#
# i would like to have some information about trains to chiangmai now .
#
#
#
# be dead are the headlight .
#
#
#
# check we will give you well .
#
#
#
# would you close my account ?
#
#
#
# are you free this evening ?
#
#
#
# by the way , do have of happy hour in the chinese restaurants from seven until eight tonight . the food there in the such time , you may makatamasa a discount .
#
#
#
# you can call again for here in about an hour .
#
#
#
# ok , now have understood what i i
#
#
#
# good . that is the i would like !
#
#
#
# i have come to tell you going the mum and i at the theatre this coming saturday .
#
#
#
# here is my claim checks .
#
#
#
# i do not have any cannot buwisan .
#
#
#
# please paghaluin the grated radish with the sauce and then dip the tempura in it before eating .
#
#
#
# here is your passport , and is the key .
#
#
#
# think i that is my flight in the public address system . better leave am .
#
#
#
# i am very sorry for the my pagkapabaya .
#
#
#
# i would like a irish coffee .
#
#
#
# where is the nearest bank ?
#
#
#
# have an appointment will try it out for you .
#
#
#
# two toast and a cup of coffee .
#
#
#
# not , it is free of charge .
#
#
#
# i would like to to go straight to t .
#
#
#
# you need not if that all there is you .
#
#
#
# would you like a high for your child boy ?
#
#
#
# what kind of soft drinks do you have ?
#
#
#
# where do i buy the ticket ?
#
#
#
# how you all . i am a exchange student from canada .
#
#
#
# i need a slide film for this camera .
#
#
#
# would you care to go and play tennis with me ?
#
#
#
# what kind of fish would you like ?
#
#
#
# how about if a bottle of soda water ?
#
#
#
# how is the temperature of the wine ?
#
#
#
# i think the scene to nakabighani me a husto a little nakikipag-usap the magkapatid in the isat-isa
#
# /bin/sh: 2: Syntax error: Unterminated quoted string
#
# another piece of fried steak ?
# often takes it 2 day put ourselves in trouble . but i would like do you express service or same day ?
#
#
#
# stay in the hospital a few days ? to magpagaling.
#
#
#
# push you only it under the berth .
#
#
#
# i do not take pork .
#
#
#
# what kind of car do you have ?
#
#
#
# i have a reservation .
#
#
#
# how am i going to pay for here ?
#
#
#
# can you give me some suggestions ?
#
#
#
# i cannot eat pork .
#
#
#
# miss . may i have the bill please ?
#
#
#
# thank you , sir .
#
#
#
# what time have i got to get there ?
#
#
#
# in twenty until thirty dollars per person .
#
#
#
# kayumanggi and moderate the big .
#
#
#
# how long does it take me if malalakad ?
#
#
#
# is equipped with a bath in the back of the door . from 7 a.m. until 12 p.m. the supply some hot water
#
#
#
# what we should do if tuluyang lost or is partly damaged our padala ?
#
#
#
# if would you like of any additional food , please call much do you measure just i am .
#
#
#
# can you ideliver it for me ?
#
#
#
# how long will it take ?
#
#
#
# yes , sir . i need to iulat the pananakaw in the my car .
#
#
#
# what time does the train ?
#
#
#
# i feel to i would like to make a things tonight .
#
#
#
# one in the most wonderful are piyesa to i did hear ' the night of spring flowers , river , lost and moon .
#
#
#
# how much please ?
#
#
#
# that is quite all right .
#
#
#
# can you book on that flight . ?
#
#
#
# excuse me , can i order books it ?
#
#
#
# if ilalagda your name here , you will be charged for a hotel in your departure
#
#
#
# makakapagbigay i am a change .
#
#
#
# what is the served you today ?
#
#
#
# which routes goes to the bangkok ?
#
#
#
# a milk , two sugar , please .
#
#
#
# excess umiinit the engine .
#
#
#
# how long would a game ?
#
#
#
# into we in huahin in a few minutes . there will be a many nagtitinda of food on the platform there .
#
#
#
# you sell even what books english-language ?
#
#
#
# how kahabang stay have you in thailand ?
#
#
#
# we have should pag-usapan .
#
#
#
# can you make a right turn at the next corner ?
#
#
#
# how you pay ?
#
#
#
# i just wondered why is it nagtatamasa a little such are really a big popularidad .
#
#
#
# are 6 : 00 .
#
#
#
# as naplano , visit we get the some famous caves .
#
#
#
# what does the fare come to ?
#
#
#
# where is the silom subway station ?
#
#
#
# yes , on time the train .
#
#
#
# what should i dial for make an international call ?
#
#
#
# would you of a room there cable tv ?
#
#
#
# which train giving fastest service from nakornpathom until nakorn is thammarat ?
#
#
#
# sadya it left in the palapagan , for i get here before you magsara for day .
#
#
#
# where can we get of boarding pass ?
#
#
#
# be was everything alright ? my camera in the overhead compartment .
#
#
#
# naiipit my toenails .
#
#
#
# where is the suite ?
#
#
#
# do you accept checks ?
#
#
#
# over there it to the counter .
#
#
#
# for are resident a hotel is this the bar
#
#
#
# is cable tv your rooms ?
#
#
#
# for only personal use them .
#
#
#
# very good .
#
#
#
# i cannot find reserved seat we arrive . where will certainly take good care of them ?
#
#
#
# have you size m stock ?
#
#
#
# if you want to smoke , please transfer to you got on the one of my hobbies lamesang that .
#
#
#
# may i ask how much is the fare ?
#
#
#
# c baht altogether .
#
#
#
# you join us in playing cards ?
#
#
#
# sorry because weak my pakikinig. can you repeat that .
#
#
#
# which is my stop ?
#
#
#
# near it n.w. 5 ?
#
#
#
# are you our catalogue along you for this computer ?
#
#
#
# i would like to pay by card ?
#
#
#
# please prepare some popular guangdong fruit , like bananas , mangga , pineapple and else .
#
#
#
# open it in the time start the train .
#
#
#
# have you any valuables ?
#
#
#
# when shall i come to get the ticket ?
#
#
#
# please mag-inggat .
#
#
#
# boiled just for paghuhugas of hands , face and pagmumumog the water here , not for pag-inom .
#
#
#
# please give please me to my change , please .
#
#
#
# how long think you it takes to fix it ?
#
#
#
# dumplings in coconut cream
#
#
#
# some word just
#
#
#
# that is good .
#
#
#
# i am afraid that these dishes are dumaragdag my weight these last day .
#
#
#
# same is the exchange rate in the are bank .
#
#
#
# all right . may you make sure to fasten again your shirt and coat now .
#
#
#
# can you washed it for me ?
#
#
#
# pass me the pepper , please .
#
#
#
# it is your luggage ticket .
#
#
#
# is it possible for me to make a mag water-ski over there ?
#
#
#
# does directly the train is about to pass over the bangkok ?
#
#
#
# i expected to gumana it . it is not mumurahing radio is is good workmanship it .
#
#
#
# welcome pagbabalik , sir .
#
#
#
# outside we in the garden .
#
#
#
# which beach go you ?
#
#
#
# eggs and pork in the red sauce
#
#
#
# i need to get there by 11 : 30 .
#
#
#
# do you know where the nearest bus stop ?
#
#
#
# can i get a cash for these travelers
#
# /bin/sh: 2: Syntax error: Unterminated quoted string
#
# thank you , sir .
#
#
#
# if you do not like to madistorbo , put is only
#
# there is plenty of time for gets on the train .
#
#
#
# fish curry in banana leaf
#
#
#
# what is the a doggie bag ?
#
#
#
# with kabagal it if ihahambing in a plane , but we can enjoy are the bukid , mountain and these are river in beside the railway station .
#
#
#
# what is this for ?
#
#
#
# please papuntahin the taxi here at the holiday inn now .
#
#
#
# my ankle is sprained .
#
#
#
# i will take it for you .
#
#
#
# i would like a two person room .
#
#
#
# what is the difference between time of bangkok and gmt ( greenwich mean time tables ) ?
#
#
#
# surely i am not pay the service charge .
#
#
#
# i get a refund here ?
#
#
#
# napakamakatwiran it .
#
#
#
# palagian excess umiinit the engine .
#
#
#
# can you make change for 50 baht ?
#
#
#
# is there hospital at the next station ?
#
#
#
# that is very kind of you . thank
#
#
#
# is the train on time ?
#
#
#
# but you can transfer to from this bus on the bus no.33 when have we get the 1st street .
#
#
#
# fast food restaurant
#
#
#
# i would like a skin .
#
#
#
# vichyssoise , please .
#
#
#
# can you like some more it lower a little ?
#
#
#
# sinusubok to stop .
#
#
#
# how about if seven oclock
#
# /bin/sh: 2: Syntax error: Unterminated quoted string
#
# just a moment , please . let me have a look .
#
#
#
# how much more time will do we have ?
#
#
#
# we have many people now .
#
#
#
# went napakamatulungin you .
#
#
#
# flat bread to nilublob in the curry sauce
#
#
#
# well , quite a few years you have with you which is ?
#
#
#
# but i have pay as you balance .
#
#
#
# with extra charge , i suppose ?
#
#
#
# what is the difference a single fare and a round trip tickets ?
#
#
#
# thank you .
#
#
#
# what grupong popular in thailand ?
#
#
#
# be is very tiring be allowed to take the train such a long weather .
#
#
#
# sorry , already reserved all these window table .
#
#
#
# okay just been to if i smoke ?
#
#
#
# over there over there . let me show you .
#
#
#
# leave my flight at 10.00 evening .
#
#
#
# is ready all .
#
#
#
# not too much .
#
#
#
# hope find you again .
#
#
#
# we can leave the bathroom decorate of tubero to do are the pag-aayos .
#
#
#
# the restaurant is open for morning tea from 7 : 00 a.m. until 9 : 00 a.m.
#
#
#
# it depends on what weather it .
#
#
#
# or , one more overeating famous movie .
#
#
#
# where is our berth ?
#
#
#
# can you still make a reduction a little beside ?
#
#
#
# how many races are on the have now ?
#
#
#
# it is a pleasure to serve you .
#
#
#
# you should stay in bed for a one or two day .
#
#
#
# it is the embarkation / disembarkation card .
#
#
#
# can i get a taxi around here ?
#
#
#
# favourite actor is leonardo dicaprio .
#
#
#
# i want to have a pair of binurdahang shoes .
#
#
#
# ham sandwich , please .
#
#
#
# i get that later ?
#
#
#
# possible still to get ticket for tonight ?
#
#
#
# fill up the gas when will return the car to us .
#
#
#
# i would like to make a withdrawal .
#
#
#
# i would like to have again my things from the safe .
#
#
#
# good morning .
#
#
#
# where you play much tennis ?
#
#
#
# has pulled in your suitcase .
#
#
#
# how much is the extra bus fare ?
#
#
#
# what is the distance between bangkok and huahin ?
#
#
#
# what ferries are work the we will have tonight ?
#
#
#
# allowed you smoking ?
#
#
#
# from where ?
#
#
#
# that is not good news .
#
#
#
# where is the car rental ?
#
#
#
# do you know where that ?
#
#
#
# are tax-refund form ? your office ?
#
#
#
# three minutes more , over there we are .
#
#
#
# you mean that i will not mangangailangang change trains ?
#
#
#
# breathe deeply .
#
#
#
# and now ?
#
#
#
# ice cream
#
#
#
# where is the mess , exactly ?
#
#
#
# i will ask the dining-car attendant who to go and can to tell him what the you would like .
#
#
#
# i do not know the their number .
#
#
#
# certainly , sir .
#
#
#
# seems to missing my baggage .
#
#
#
# bye .
# i would like a tour of the city .
#
#
#
# send the airport suitcase in your hotel .
#
#
#
# i do not know your railway regulations .
#
#
#
# what are kind of soup do you have today ?
#
#
#
# a table for five at eight .
#
#
#
# open ? restaurant for breakfast ?
#
#
#
# lilinaw all the in just a few minutes .
#
#
#
# is there anything else that you are there one vacant over there in your flight in tuesday ?
#
#
#
# here is
#
# where you have , sir ?
#
#
#
# whose should i give the key ?
#
#
#
# with large you difference in fare a hard berth and a soft one ?
#
#
#
# need i also have a look at your drivers
#
# /bin/sh: 2: Syntax error: Unterminated quoted string
#
# be there , i but there many people , and i am not a less what took .
#
#
#
# i will check your order .
#
#
#
# how much is the total ?
#
#
#
# please give me a glass of water .
#
#
#
# very much to seen it again .
#
#
#
# it is . it is a new park , do not you ?
#
#
#
# i am sorry i am late .
#
#
#
# how do you like the rest of the seat in the smoking or in the non-smoking section ?
#
#
#
# she sang well , i thought .
#
#
#
# what time we cannot meals ?
#
#
#
# what is the problem ?
#
#
#
# better get some fresh air on the platform , but do not go of too far , please .
#
#
#
# do not put down , please .
#
#
#
# i prefer the green than other color , especially in my sombrero .
#
#
#
# local , i i have just familiar with the routes here .
#
#
#
# i want to reserve a seat on the the non-smoking section .
#
#
#
# i would like a plunger .
#
#
#
# i would like to buy a panyo for my son's
#
#
#
# have any seat on this train . to chiang mai ?
#
#
#
# do you know where i am still find it ?
#
#
#
# be is delicious a iced coke .
#
#
#
# where is the reservation ?
#
#
#
# tell me where to go .
#
#
#
# how should i be manamit ?
#
#
#
# where do you want to go holiday like to go for your summer it ?
#
#
#
# if you want to order a room service , just press the
#
# the be dead here .
#
#
#
# since yesterday .

# %%
file = open('smt-result.data.eval', 'w')

for out in output:
    if out != "\n":
        file.write(out)
    
file.close()
